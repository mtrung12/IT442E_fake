# %%
import pandas as pd

# %%
df1 = pd.read_csv('mogi_export.csv')
df2 = pd.read_csv('nhatot.csv')

# %%
df1.head()
# Out:
#              street                 ward           district     city   size  \
# 0     Tôn Đức Thắng      Phường Hòa Minh    Quận Liên Chiểu  Đà Nẵng   60.8
# 1  Nguyễn Văn Thoại           Bắc Phú Mỹ  Quận Ngũ Hành Sơn  Đà Nẵng  110.0
# 2      Xuân Thiều 8  Phường Hòa Hiệp Nam    Quận Liên Chiểu  Đà Nẵng   80.0
# 3       Lê Duy Đình        Phường An Khê     Quận Thanh Khê  Đà Nẵng   76.0
# 4           Lê Duẩn     Phường Tân Chính     Quận Thanh Khê  Đà Nẵng  108.3
#
#   property_legal_document  bed_rooms  toilets  floors            price  \
# 0                   Sổ đỏ        4.0      1.0     2.0   5 tỷ 800 triệu
# 1                   Sổ đỏ        6.0      5.0     NaN  13 tỷ 300 triệu
# 2                   Sổ đỏ        2.0      1.0     NaN   3 tỷ 600 triệu
# 3                 Sổ hồng        4.0      4.0     4.0   7 tỷ 200 triệu
# 4                   Sổ đỏ        4.0      3.0     NaN  15 tỷ 500 triệu
#
#      house_type
# 0  nhà mặt tiền
# 1  nhà mặt tiền
# 2  nhà mặt tiền
# ...

# %%
df2.head()
# Out:
#           price   size  bed_rooms  toilets             house_type  \
# 0  1.930000e+09   64.0        2.0      2.0                    NaN
# 1  6.000000e+09  100.0        NaN      NaN                    NaN
# 2  1.000000e+10   72.0        4.0      4.0           Nhà ngõ, hẻm
# 3  6.000000e+08   32.0        1.0      1.0                    NaN
# 4  4.800000e+08  105.4        3.0      2.0  Nhà mặt phố, mặt tiền
#
#   property_legal_document            city              district  \
# 0             Đang chờ sổ  Tp Hồ Chí Minh           Quận Gò Vấp
# 1                Đã có sổ      Bình Dương       Thành phố Dĩ An
# 2                Đã có sổ  Tp Hồ Chí Minh               Quận 10
# 3                       1      Bình Thuận  Thành phố Phan Thiết
# 4                Đã có sổ  Tp Hồ Chí Minh      Huyện Bình Chánh
#
#              ward                                             street  floors
# 0       Phường 14     số 59 Đường 57, phường 14, quận Gò Vấp, Tp.HCM     NaN
# ...

# %%
df_combined = pd.concat([df1, df2], ignore_index=True)
display(df_combined.head())
# Out:
#              street                 ward           district     city   size  \
# 0     Tôn Đức Thắng      Phường Hòa Minh    Quận Liên Chiểu  Đà Nẵng   60.8
# 1  Nguyễn Văn Thoại           Bắc Phú Mỹ  Quận Ngũ Hành Sơn  Đà Nẵng  110.0
# 2      Xuân Thiều 8  Phường Hòa Hiệp Nam    Quận Liên Chiểu  Đà Nẵng   80.0
# 3       Lê Duy Đình        Phường An Khê     Quận Thanh Khê  Đà Nẵng   76.0
# 4           Lê Duẩn     Phường Tân Chính     Quận Thanh Khê  Đà Nẵng  108.3
#
#   property_legal_document  bed_rooms  toilets  floors            price  \
# 0                   Sổ đỏ        4.0      1.0     2.0   5 tỷ 800 triệu
# 1                   Sổ đỏ        6.0      5.0     NaN  13 tỷ 300 triệu
# 2                   Sổ đỏ        2.0      1.0     NaN   3 tỷ 600 triệu
# 3                 Sổ hồng        4.0      4.0     4.0   7 tỷ 200 triệu
# 4                   Sổ đỏ        4.0      3.0     NaN  15 tỷ 500 triệu
#
#      house_type
# 0  nhà mặt tiền
# 1  nhà mặt tiền
# 2  nhà mặt tiền
# ...

# %%
df_combined.shape
# Out:
# (10604, 11)

# %%
df_combined.to_csv('integrate.csv', index=False)
